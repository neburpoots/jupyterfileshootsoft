# %%
import cv2

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img1 = cv2.imread('blackwhitetarget.png')
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2 = cv2.imread('shootanalysisdataset/shotnobg.png')
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def display(img,cmap='gray'):
    fig = plt.figure(figsize=(12,10))
    ax = fig.add_subplot(111)
    ax.imshow(img,cmap='gray')

# %%
plt.imshow(img1)

# %%
large_img = img1
small_img = img2
x_offset = 500
y_offset = 600
x_max = large_img.shape[1] - small_img.shape[1]
y_max = large_img.shape[0] - small_img.shape[0]

# %%
small_img.shape
# Out:
# (197, 257, 3)

# %%
large_img[y_offset:y_end,x_offset:x_end] = small_img

# %%
plt.imshow(large_img)

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# Reading the input image
img = cv2.imread('shootanalysisdataset/schotanalyse/20200923_130835.jpg', 0)

# Taking a matrix of size 5 as the kernel
kernel = np.ones((5, 5), np.uint8)
  
# The first parameter is the original image,
# kernel is the matrix with which image is
# convolved and third parameter is the number
# of iterations, which will determine how much
# you want to erode/dilate a given image.
img_erosion = cv2.erode(img, kernel, iterations=1)
img_dilation = cv2.dilate(img, kernel, iterations=1)
  
plt.imshow(img_dilation)

# %%
plt.imshow(img_erosion)

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

kernel = np.ones((5, 5), np.uint8)

img2 = cv2.imread('shootanalysisdataset/schotanalyse/20200923_130907.jpg')
resized_img = cv2.resize(img2, (round((img2.shape[1] / 4)), round((img2.shape[0] / 4))))

kernel = np.ones((5, 5), np.uint8)
img = cv2.erode(resized_img, kernel, iterations=1)

greyresized = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
sep_blur = cv2.blur(greyresized,(8,8))

sep_thresh = cv2.adaptiveThreshold(sep_blur,255,
                                   cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                                   cv2.THRESH_BINARY,11,3)
img_erosionv2 = cv2.erode(sep_thresh, kernel, iterations=1)

minDist = 0.0001
param1 = 850 #500
param2 = 300 #200 #smaller value-> more false circles
minRadius = 5
maxRadius = 1200 #10

# docstring of HoughCircles: HoughCircles(image, method, dp, minDist[, circles[, param1[, param2[, minRadius[, maxRadius]]]]]) -> circles
circles = cv2.HoughCircles(img_erosionv2, 
                           cv2.HOUGH_GRADIENT, 
                           1, minDist, 
                           param1=param1, 
                           param2=param2, 
                           minRadius=minRadius, 
                           maxRadius=maxRadius)


if circles is not None:
    circles = np.uint16(np.around(circles))
    for i in circles[0,:]:
        cv2.circle(img2, (i[0], i[1]), i[2], (0, 255, 0), 2)

# Show result for testing:
plt.imshow(img2)
display(img2)

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

kernel = np.ones((5, 5), np.uint8)

img2 = cv2.imread('shootanalysisdataset/schotanalyse/20200923_130927.jpg',0)
resized_img = cv2.resize(img2, (round((img2.shape[1] / 4)), round((img2.shape[0] / 4))))

sep_blur = cv2.medianBlur(resized_img,25)

minDist = 0.0001
param1 = 200 #500
param2 = 200 #200 #smaller value-> more false circles
minRadius = 5
maxRadius = 1200 #10

# docstring of HoughCircles: HoughCircles(image, method, dp, minDist[, circles[, param1[, param2[, minRadius[, maxRadius]]]]]) -> circles
circles = cv2.HoughCircles(sep_blur, cv2.HOUGH_GRADIENT, 1, minDist, param1=param1, param2=param2, minRadius=minRadius, maxRadius=maxRadius)


if circles is not None:
    circles = np.uint16(np.around(circles))
    for i in circles[0,:]:
        cv2.circle(resized_img, (i[0], i[1]), i[2], (0, 255, 0), 2)

# Show result for testing:
plt.imshow(sep_blur)
cv2.imshow('test', resized_img)
cv2.imshow('blurred', sep_blur)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

kernel = np.ones((5, 5), np.uint8)

#img = cv2.imread('shootanalysisdataset/schotanalyse/20200923_130848.jpg')
#img.shape
#resized_img = cv2.resize(img, (round((img.shape[1] / 4)), round((img.shape[0] / 4))))
#img_dilation = cv2.dilate(resized_img, kernel, iterations=2)
#imagem = cv2.bitwise_not(resized_img)
#img_erosion = cv2.erode(imagem, kernel, iterations=1)




img2 = cv2.imread('shootanalysisdataset/schotanalyse/20200923_130835.jpg')
resized_img = cv2.resize(img2, (round((img2.shape[1] / 4)), round((img2.shape[0] / 4))))


greyresized = cv2.cvtColor(resized_img, cv2.COLOR_BGR2GRAY)
sep_blur = cv2.blur(greyresized,(4,4))


kernel = np.ones((5, 5), np.uint8)


sep_thresh = cv2.adaptiveThreshold(sep_blur,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,11,8)

img_dilation = cv2.dilate(sep_thresh, kernel, iterations=2)

img_erosionv2 = cv2.erode(sep_thresh, kernel, iterations=1)


minDist = 0.00000000001
param1 = 1 #500
param2 = 200 #200 #smaller value-> more false circles
minRadius = 1
maxRadius = 1200 #10

# docstring of HoughCircles: HoughCircles(image, method, dp, minDist[, circles[, param1[, param2[, minRadius[, maxRadius]]]]]) -> circles
circles = cv2.HoughCircles(img_erosionv2, cv2.HOUGH_GRADIENT, 1, minDist, param1=param1, param2=param2, minRadius=minRadius, maxRadius=maxRadius)

if circles is not None:
    circles = np.uint16(np.around(circles))
    for i in circles[0,:]:
        cv2.circle(resized_img, (i[0], i[1]), i[2], (0, 255, 0), 2)

# Show result for testing:
cv2.imshow('test', resized_img)
cv2.imshow('blurred', img_erosionv2)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 52>()
#      50 cv2.imshow('test', resized_img)
#      51 cv2.imshow('blurred', img_erosionv2)
# ---> 52 cv2.waitKey(0)
#      53 cv2.destroyAllWindows()
#
# KeyboardInterrupt:

# %%
#!/usr/bin/env python

import cv2
import numpy as np
import matplotlib.pyplot as plt

kernel = np.ones((5, 5), np.uint8)

image = cv2.imread('shootanalysisdataset/schotanalyse/20200923_130914.jpg')
resized_img = cv2.resize(image, (round((image.shape[1] / 4)), round((image.shape[0] / 4))))
img_dilation = cv2.dilate(resized_img, kernel, iterations=2)
imagem = cv2.bitwise_not(resized_img)
img_erosion = cv2.erode(imagem, kernel, iterations=1)

output = resized_img.copy()
img = cv2.cvtColor(img_erosion, cv2.COLOR_BGR2GRAY)
# Find circles
circles = cv2.HoughCircles(img, cv2.HOUGH_GRADIENT, 1, 80, 500)
# If some circle is found
if circles is not None:
   # Get the (x, y, r) as integers
   circles = np.round(circles[0, :]).astype("int")
   print(circles)
   # loop over the circles
   for (x, y, r) in circles:
      cv2.circle(output, (x, y), r, (0, 255, 0), 2)
# show the output image
plt.imshow(output)
plt.imshow(blurred)
cv2.imshow('test', output)
cv2.imshow('blurred', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# [[372 504 115]]

# %%
img = cv2.imread('shootanalysisdataset/schotanalyse/20200923_131212.jpg')
img.shape
resized_img = cv2.resize(img, (round((img.shape[1] / 4)), round((img.shape[0] / 4))))
dst = cv2.fastNlMeansDenoisingColored(resized_img,None,10,10,7,21)
img_dilation = cv2.dilate(dst, kernel, iterations=2)
imagem = cv2.bitwise_not(resized_img)
img_erosion = cv2.erode(imagem, kernel, iterations=2)
# The declaration of CLAHE|
# clipLimit -> Threshold for contrast limiting
image_bw = cv2.cvtColor(img_erosion, cv2.COLOR_BGR2GRAY)

clahe = cv2.createCLAHE(clipLimit = 5)
final_img = clahe.apply(image_bw) + 30
plt.imshow(final_img, cmap='gray')

# %%
def draw_circles(img, circles):
    cimg = img.copy()
    for i in circles[0,:]:
    # draw the outer circle
        cv2.circle(cimg,(i[0],i[1]),i[2],(0,255,0),2)
        # draw the center of the circle
        cv2.circle(cimg,(i[0],i[1]),2,(0,0,255),3)
        cv2.putText(cimg,str(i[0])+str(',')+str(i[1]), (i[0],i[1]), cv2.FONT_HERSHEY_SIMPLEX, 0.4, 255)
    return cimg

def detect_circles(image_path):
    # open color image
    image = cv2.imread(image_path)
    image_blur = cv2.medianBlur(image, 3)
    # find edges
    edges = cv2.Canny(image_blur, 5, 50)
    # let's clean the neighboring pixels
    edges = cv2.medianBlur(edges, 3)

    circles = cv2.HoughCircles(edges, cv2.HOUGH_GRADIENT, 2, 80, param1=100, param2=45, minRadius=20, maxRadius=40)
    cimg = draw_circles(image, circles)
    print("{} circles detected.".format(circles[0].shape[0]))
    return cimg
detect_circles('shootanalysisdataset/schotanalyse/20200923_131212.jpg')
# Out:
# 151 circles detected.
# array([[[ 18,  18,  18],
#         [ 18,  18,  18],
#         [ 17,  17,  17],
#         ...,
#         [ 12,  94, 176],
#         [ 10,  92, 174],
#         [ 11,  93, 175]],
#
#        [[ 11,  11,  11],
#         [ 11,  11,  11],
#         [  9,   9,   9],
#         ...,
#         [ 16,  98, 180],
#         [  3,  85, 167],
#         [  0,  81, 163]],
#
#        [[  6,   6,   6],
#         [  6,   6,   6],
#         [  2,   2,   2],
#         ...,
#         [ 26, 108, 190],
#         [ 10,  92, 174],
#         [ 10,  92, 174]],
#
#        ...,
#
#        [[ 13,  24,  44],
#         [  9,  20,  40],
#         [  8,  19,  39],
#         ...,
#         [146, 151, 154],
#         [149, 154, 157],
#         [149, 154, 157]],
#
#        [[  0,   1,  21],
#         [  0,   8,  28],
#         [  9,  20,  40],
#         ...,
#         [154, 159, 162],
#         [164, 169, 172],
#         [165, 170, 173]],
#
#        [[  0,   0,  15],
#         [  0,   1,  21],
# ...

# %%
import cv2
import numpy as np

standard_img = cv2.imread('shootanalysisdataset/schotanalyse/20200923_131212.jpg', 1)
img = cv2.resize(standard_img, (round((standard_img.shape[1] / 4)), round((standard_img.shape[0] / 4))))

# converting to LAB color space
lab= cv2.cvtColor(standard_img, cv2.COLOR_BGR2LAB)
l_channel, a, b = cv2.split(lab)

# Applying CLAHE to L-channel
# feel free to try different values for the limit and grid size:
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
cl = clahe.apply(l_channel)

# merge the CLAHE enhanced L-channel with the a and b channel
limg = cv2.merge((cl,a,b))

# Converting image from LAB Color model to BGR color spcae
enhanced_img = cv2.cvtColor(limg, cv2.COLOR_LAB2BGR)

# Stacking the original image with the enhanced image
cv2.imshow('Result', img)

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

kernel = np.ones((5, 5), np.uint8)

img = cv2.imread('shootanalysisdataset/schotanalyse/20200923_130835.jpg')
img.shape
resized_img = cv2.resize(img, (round((img.shape[1] / 4)), round((img.shape[0] / 4))))
img_erosion = cv2.erode(resized_img, kernel, iterations=1)

gray = cv2.cvtColor(img_erosion, cv2.COLOR_BGR2GRAY)

blurred = cv2.medianBlur(gray, 5) #cv2.bilateralFilter(gray,10,50,50)

plt.imshow(blurred)

minDist = 0.00000000001
param1 = 1 #500
param2 = 400 #200 #smaller value-> more false circles
minRadius = 1
maxRadius = 1200 #10

# docstring of HoughCircles: HoughCircles(image, method, dp, minDist[, circles[, param1[, param2[, minRadius[, maxRadius]]]]]) -> circles
circles = cv2.HoughCircles(blurred, cv2.HOUGH_GRADIENT, 1, minDist, param1=param1, param2=param2, minRadius=minRadius, maxRadius=maxRadius)

if circles is not None:
    circles = np.uint16(np.around(circles))
    circles[0,:,2].max()
    outerCircle = circles[0,:][0]
    
    cv2.circle(img_erosion, (outerCircle[0], outerCircle[1]), outerCircle[2], (0, 255, 0), 2)
    
    # 81/2
    radius = outerCircle[2]
    distance_between_circles = radius / 8.50
    
    i = 1
    while (i < 9):    
        newRadius = radius - (i * distance_between_circles)
        cv2.circle(img_erosion, (outerCircle[0], outerCircle[1]), np.uint16(np.around(newRadius)), (0, 255, 0), 2)
        i += 1

# Show result for testing:
plt.imshow(img_erosion)
cv2.imshow('test', img_erosion)
cv2.imshow('blurred', blurred)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
bplt.imshow(blurred)

# %%
circles[0,:][0]
# Out:
# array([384, 526, 339], dtype=uint16)

# %%
outerCircle = circles[0,:][0]
    # 81/2
radius = outerCircle[2]
distance_between_circles = radius / 8.50
radius
distance_between_circles
type(radius)
# Out:
# numpy.uint16

# %%
plt.imshow(gray)

# %%
img.shape[0] / 2
# Out:
# 2016.0

# %%
newWidth
# Out:
# 1008.0

# %%
import cv2
import numpy as np

# Load image, grayscale, median blur, Otsus threshold

import matplotlib.pyplot as plt

kernelErosion = np.ones((5, 5), np.uint8)

image = cv2.imread('shootanalysisdataset/schotanalyse/20200923_130835.jpg')
image.shape
resized_img = cv2.resize(image, (round((image.shape[1] / 4)), round((image.shape[0] / 4))))
img_erosion = cv2.erode(resized_img, kernelErosion, iterations=2)

gray = cv2.cvtColor(img_erosion, cv2.COLOR_BGR2GRAY)


blur = cv2.medianBlur(gray, 11)
thresh = cv2.threshold(blur, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]

# Morph open 
kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5,5))
opening = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, kernel, iterations=3)

# Find contours and filter using contour area and aspect ratio
cnts = cv2.findContours(opening, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts = cnts[0] if len(cnts) == 2 else cnts[1]
for c in cnts:
    peri = cv2.arcLength(c, True)
    approx = cv2.approxPolyDP(c, 0.04 * peri, True)
    area = cv2.contourArea(c)
    if len(approx) > 5 and area > 1000 and area < 500000:
        ((x, y), r) = cv2.minEnclosingCircle(c)
        cv2.circle(img_erosion, (int(x), int(y)), int(r), (36, 255, 12), 2)


plt.imshow(img_erosion)

# %%
cv2.imshow('thresh', thresh)
cv2.imshow('opening', opening)

# %%
import cv2
import numpy as np


img = cv2.imread('shootanalysisdataset/schotanalyse/20200923_130835.jpg', 0)

cimg = cv2.cvtColor(img,cv2.COLOR_GRAY2BGR)

minDist = 0

circles = cv2.HoughCircles(img,cv2.HOUGH_GRADIENT,1,minDist,
                param1=150,param2=80,minRadius=0,maxRadius=0)


print(circles)

#print("Number of circles detected ", circles.length)


circles = np.uint16(np.around(circles))

for i in circles[0,:]:
    # draw the outer circle
    cv2.circle(cimg,(i[0],i[1]),i[2],(0,255,0),2)
    # draw the center of the circle
    cv2.circle(cimg,(i[0],i[1]),2,(0,0,255),3)

##cv2.imwrite('detected_circle.jpg',cimg)
cv2.imshow('detected circles',cimg)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-1-ac21742ab083> in <module>
#      10
#      11 circles = cv2.HoughCircles(img,cv2.HOUGH_GRADIENT,1,minDist,
# ---> 12                 param1=150,param2=80,minRadius=0,maxRadius=0)
#      13
#      14
#
# error: OpenCV(3.4.2) C:\Miniconda3\conda-bld\opencv-suite_1534379934306\work\modules\imgproc\src\hough.cpp:1741: error: (-211:One of arguments' values is out of range) dp, min_dist, canny_threshold and acc_threshold must be all positive numbers in function 'cv::HoughCircles'
