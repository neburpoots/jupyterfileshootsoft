# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def display(img,cmap='gray'):
    fig = plt.figure(figsize=(12,10))
    ax = fig.add_subplot(111)
    ax.imshow(img,cmap='gray')

# %%
img2 = cv2.imread('shootanalysisdataset/schotanalyse/20200923_131046.jpg')

kernel = np.ones((5, 5), np.uint8)

resized_img = cv2.resize(img2, (round((img2.shape[1] / 4)), round((img2.shape[0] / 4))))
img_dilation = cv2.dilate(img2, kernel, iterations=1)
imagem = cv2.bitwise_not(img_dilation)

img_erosion = cv2.erode(img2, kernel, iterations=2)

# %%
display(img_erosion)

# %%
display(img2)

# %%
# Median blur
# Grayscale
# Binary threshold
# Find Contours

# %%
sep_blur = cv2.blur(resized_img,(20,20))

# %%
display(sep_blur)

# %%
gray_sep_coins = cv2.cvtColor(img_erosion, cv2.COLOR_BGR2GRAY)
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
final_img = clahe.apply(gray_sep_coins)

# %%
display(final_img)

# %%
#ret, sep_thresh = cv2.threshold(gray_sep_coins,170,255,cv2.ADAPTIVE_THRESH_MEAN_C  )

img_dilation = cv2.dilate(img2, kernel, iterations=1)
img_erosionv2 = cv2.erode(img2, kernel, iterations=1)

greyresized = cv2.cvtColor(img_erosionv2, cv2.COLOR_BGR2GRAY)
sep_blur = cv2.blur(greyresized,(4,4))


kernel = np.ones((5, 5), np.uint8)


sep_thresh = cv2.adaptiveThreshold(sep_blur,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,11,2)

# %%
display(sep_thresh)

# %%
contours,hierarchy = cv2.findContours(sep_thresh.copy(),cv2.RETR_CCOMP,cv2.CHAIN_APPROX_SIMPLE)

# %%
contour_list = []
for contour in contours:
    approx = cv2.approxPolyDP(contour,0.01*cv2.arcLength(contour,True),True)
    area = cv2.contourArea(contour)
    if ((len(approx) > 8) & (area > 1000) ):
        contour_list.append(contour)



plt.imshow(resized_img)

def scale_contour(cnt, scale):
    M = cv2.moments(cnt)
    cx = int(M['m10']/M['m00'])
    cy = int(M['m01']/M['m00'])

    cnt_norm = cnt - [cx, cy]
    cnt_scaled = cnt_norm * scale
    cnt_scaled = cnt_scaled + [cx, cy]
    cnt_scaled = cnt_scaled.astype(np.int32)

    return cnt_scaled

center_coordinates = np.zeros((0,3))
#GETS THE CENTER COORDINATES PLAN IS TO REMOVE OUTLIERS
for x, contour, in enumerate(contour_list):
    M = cv2.moments(contour)
    cx = int(M['m10']/M['m00'])
    cy = int(M['m01']/M['m00'])

    center_coordinates = np.vstack([center_coordinates, [cx, cy, x]])


    

for contour in contour_list:
    M = cv2.moments(contour)
    cx = int(M['m10']/M['m00'])
    cy = int(M['m01']/M['m00'])
    cv2.circle(resized_img, (cx, cy), 7, (255, 0, 255), -1)


cv2.drawContours(img_erosion, contour_list,  -1, (255,0,0), 2)

    
#double_contour = scale_contour(contour_list[0], 0.45)

#cv2.drawContours(img2, [double_contour],  -1, (255,0,0), 2)

plt.imshow(img_erosion)

# %%
average_y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-d539883e0341> in <module>
# ----> 1 average_y
#
# NameError: name 'average_y' is not defined

# %%
a = np.array([[1,2,3]])
l = [4,5,6]
np.vstack([a,l])
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
center_coordinates
# Out:
# array([[1.361e+03, 3.076e+03, 0.000e+00],
#        [1.804e+03, 2.647e+03, 1.000e+00],
#        [9.480e+02, 2.610e+03, 2.000e+00],
#        [1.400e+03, 2.205e+03, 3.000e+00],
#        [1.135e+03, 1.908e+03, 4.000e+00],
#        [1.376e+03, 2.675e+03, 5.000e+00],
#        [1.347e+03, 3.499e+03, 6.000e+00],
#        [1.355e+03, 3.273e+03, 7.000e+00],
#        [1.361e+03, 3.075e+03, 8.000e+00],
#        [1.389e+03, 2.758e+03, 9.000e+00],
#        [2.192e+03, 2.661e+03, 1.000e+01],
#        [1.996e+03, 2.643e+03, 1.100e+01],
#        [1.804e+03, 2.646e+03, 1.200e+01],
#        [1.382e+03, 2.647e+03, 1.300e+01],
#        [9.480e+02, 2.610e+03, 1.400e+01],
#        [1.382e+03, 2.693e+03, 1.500e+01],
#        [7.540e+02, 2.590e+03, 1.600e+01],
#        [1.379e+03, 2.592e+03, 1.700e+01],
#        [5.690e+02, 2.597e+03, 1.800e+01],
#        [1.511e+03, 2.605e+03, 1.900e+01],
#        [1.326e+03, 2.531e+03, 2.000e+01],
#        [1.403e+03, 2.762e+03, 2.100e+01],
#        [1.400e+03, 2.205e+03, 2.200e+01],
#        [1.384e+03, 2.669e+03, 2.300e+01],
#        [1.409e+03, 2.015e+03, 2.400e+01],
#        [1.378e+03, 2.732e+03, 2.500e+01],
#        [1.346e+03, 1.940e+03, 2.600e+01],
#        [1.541e+03, 1.904e+03, 2.700e+01],
#        [1.127e+03, 1.899e+03, 2.800e+01],
#        [1.416e+03, 1.850e+03, 2.900e+01],
#        [1.391e+03, 2.721e+03, 3.000e+01],
#        [1.329e+03, 3.949e+03, 3.100e+01],
#        [1.337e+03, 3.717e+03, 3.200e+01],
#        [2.580e+03, 2.673e+03, 3.300e+01],
#        [2.378e+03, 2.670e+03, 3.400e+01],
#        [3.930e+02, 2.588e+03, 3.500e+01],
#        [2.110e+02, 2.583e+03, 3.600e+01],
#        [1.376e+03, 2.676e+03, 3.700e+01],
#        [1.424e+03, 1.673e+03, 3.800e+01],
#        [1.386e+03, 2.751e+03, 3.900e+01],
#        [1.434e+03, 1.500e+03, 4.000e+01],
#        [1.331e+03, 2.731e+03, 4.100e+01],
#        [2.785e+03, 2.675e+03, 4.200e+01],
#        [3.300e+01, 2.577e+03, 4.300e+01],
#        [1.440e+03, 1.329e+03, 4.400e+01],
#        [2.016e+03, 2.198e+03, 4.500e+01],
#        [1.448e+03, 1.161e+03, 4.600e+01],
#        [1.611e+03, 1.318e+03, 4.700e+01],
#        [1.455e+03, 9.940e+02, 4.800e+01],
#        [2.916e+03, 9.360e+02, 4.900e+01],
#        [2.949e+03, 9.390e+02, 5.000e+01],
#        [2.989e+03, 9.310e+02, 5.100e+01],
#        [3.570e+02, 7.620e+02, 5.200e+01],
#        [2.650e+02, 4.400e+02, 5.300e+01],
#        [4.240e+02, 5.090e+02, 5.400e+01],
#        [3.540e+02, 6.610e+02, 5.500e+01],
#        [6.260e+02, 4.130e+02, 5.600e+01],
#        [2.630e+02, 4.350e+02, 5.700e+01],
#        [4.790e+02, 5.860e+02, 5.800e+01],
#        [2.520e+03, 2.000e+02, 5.900e+01],
#        [2.572e+03, 1.870e+02, 6.000e+01],
#        [2.795e+03, 1.740e+02, 6.100e+01],
#        [2.746e+03, 1.740e+02, 6.200e+01],
#        [2.672e+03, 1.700e+02, 6.300e+01],
#        [2.619e+03, 1.680e+02, 6.400e+01],
#        [2.298e+03, 6.600e+01, 6.500e+01],
#        [1.472e+03, 5.970e+02, 6.600e+01],
#        [4.230e+02, 5.090e+02, 6.700e+01],
#        [2.298e+03, 6.600e+01, 6.800e+01]])

# %%
display(img_erosion)

# %%
#contour_list

# %%
img = cv2.imread('shootanalysisdataset/schotanalyse/20200923_130835.jpg')

# %%
img = cv2.medianBlur(img,35)

# %%
display(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
ret, thresh = cv2.threshold(gray,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)

# %%
display(thresh)

# %%
# NOISE REMOVAL
kernel = np.ones((3,3), np.uint8)
kernel
# Out:
# array([[1, 1, 1],
#        [1, 1, 1],
#        [1, 1, 1]], dtype=uint8)

# %%
opening = cv2.morphologyEx(thresh,cv2.MORPH_OPEN,kernel,iterations=2)

# %%
display(opening)

# %%
sure_bg = cv2.dilate(opening,kernel,iterations=3)

# %%
display(sure_bg)

# %%
dist_transform = cv2.distanceTransform(opening,cv2.DIST_L2,5)

# %%
display(dist_transform)

# %%
ret, sure_fg = cv2.threshold(dist_transform,0.7*dist_transform.max(),255,0)

# %%
display(sure_fg)

# %%
sure_fg = np.uint8(sure_fg)

# %%
unknown = cv2.subtract(sure_bg,sure_fg)

# %%
display(unknown)

# %%
ret , markers = cv2.connectedComponents(sure_fg)

# %%
markers = markers + 1

# %%
markers[unknown==255] = 0

# %%
display(markers)

# %%
markers = cv2.watershed(img,markers)

# %%
display(markers)

# %%
image,contours,hierarchy = cv2.findContours(markers.copy(),cv2.RETR_CCOMP,cv2.CHAIN_APPROX_SIMPLE)

for i in range(len(contours)):
    if hierarchy[0][i][3] == -1:
        cv2.drawContours(sep_coins,contours,i,(255,0,0),10)

# %%
display(sep_coins)
